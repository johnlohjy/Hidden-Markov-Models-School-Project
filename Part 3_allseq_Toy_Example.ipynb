# %% [markdown]
# # Part 3 Toy Example for the modified viterbi function to compute k best sequences using the forward pass with beam search, Comparison of sequences is done by joint probability, the products of transition and emissions

# %% [markdown]
# ### For Function that keeps all sequences after every position is done

# %%
import os
import copy
import heapq
from project_utils import estimate_emission_parameters
from project_utils import sentence_creator_states
from project_utils import estimate_transition_parameters
from project_utils import sentence_creator_observations

# %% [markdown]
# ### Learn emission and transition parameters from training set

# %% [markdown]
# #### Read training set

# %%
filepath_ES_train = os.path.join(os.getcwd(), 'Data', 'ES', 'train')

#Read the file contents
with open(filepath_ES_train, 'r', encoding='utf-8') as file:
    file_contents_ES_train = file.readlines()
    
#Convert to training set
es_training_set = [w.strip() for w in file_contents_ES_train]

# %%
#Calculate the parameters using the training set
estimated_emission_parameters,trained_words = estimate_emission_parameters(es_training_set)

# %%
estimated_transition_parameters, all_states = estimate_transition_parameters(es_training_set)

# %% [markdown]
# ### Implement Modified Viterbi Algorithm to find k-best sequences

# %%
filepath_ES_devin = os.path.join(os.getcwd(), 'Data', 'ES', 'dev.in')

#Read the file contents
with open(filepath_ES_devin, 'r', encoding='utf-8') as file:
    file_contents_ES_devin = file.readlines()
    
es_devin = [w.strip() for w in file_contents_ES_devin]

# %% [markdown]
# #### Convert ES dev.in to a list of lists where each list is a sentence of observations

# %%
#Function to create a list of lists where each list contains only the observations of a sentence
def sentence_creator_observations(original):
    sentences = []
    sentence = []
    for i in original:
        if i!='':
            sentence.append(i)
        else:
            sentences.append(sentence)
            sentence = []
            
    if len(sentence)!=0:
        sentences.append(sentence)
    
    return sentences

# %%
es_devin = sentence_creator_observations(es_devin)

# %% [markdown]
# ### Test Modified Vertibi Algorithm with Toy Example

# %% [markdown]
# #### Get the first sentence

# %%
sentence = es_devin[0]

# %% [markdown]
# #### Append STOP state

# %%
all_states.append('STOP')

# %% [markdown]
# #### Deep copy learnt parameters from ES train earlier

# %%
emission_parameters = copy.deepcopy(estimated_emission_parameters)

# %%
transition_parameters = copy.deepcopy(estimated_transition_parameters)

# %% [markdown]
# #### Initialisation Step

# %%
k_sequences = 8

# %%
#1. Initialisation Step: Initialise a heap to store the sequences containing 
#   only the score of the START state and the START state itself
all_sequences = [(1, ['START'])]

# %% [markdown]
# #### Recursive Step of beam search from the first word to nth word (inclusive)

# %%
# Initialise a variable to keep track of the position in seq_path
seq_path_position = 0

#2. Forward Pass from the first word to nth word (inclusive)
# Recursive step of beam search 
# For each position j from the first word to nth word (inclusive)
# For each position j from the first word to nth word (inclusive)
for position in range(0, len(sentence)):
    
    print(f"LOOKING AT POSITION {position}")
        
    # Initialise a list to hold all temp sequences
    temp_sequences = []
    
    # For each sequence score and sequence path in the current top sequences
    for seq_score, seq_path in all_sequences:
        print(f"Sequence Path: {seq_path} with Sequence Score: {seq_score}")
        print(" ")

        # For each state u belonging to T at the current position except for START and STOP
        for state in all_states:
            if(state=='START' or state=='STOP'):
                continue

            # If the word appears in the training set
            if(sentence[position] in trained_words):
                # If the emission and transition has been trained before
                if((sentence[position],state) in emission_parameters.keys() and (seq_path[seq_path_position],state) in transition_parameters.keys()):
                    # Calculate the extended sequence score: 
                    # score of current seq (product of transitions and emissions in seq) *
                    # transiton prob of latest state in seq to curr_state *
                    # emission prob of observation from curr_state 
                    extended_seq_score = seq_score*transition_parameters[(seq_path[seq_path_position],state)]*emission_parameters[(sentence[position],state)]
                    
                    # Extend the sequence path
                    extended_seq_path = seq_path + [state]
                    
                    # Push the extended sequence into the heap
                    extended_seq = (extended_seq_score,extended_seq_path)
                    print(f"At state: {state}")
                    print(f"Managed to get Extended Sequence Path: {extended_seq_path} with Extended Sequence Score: {extended_seq_score}")
                    print("Pushing extended sequence into heap")
                    print(" ")
                    heapq.heappush(temp_sequences, extended_seq)
            else:
                # If the emission and transition has been trained before
                if(("#UNK#",state) in emission_parameters.keys() and (seq_path[seq_path_position],state) in transition_parameters.keys()):
                    # Calculate the extended sequence score: 
                    # score of current seq (product of transitions and emissions in seq) *
                    # transiton prob of latest state in seq to curr_state *
                    # emission prob of #UNK# from curr_state
                    extended_seq_score = seq_score*transition_parameters[(seq_path[seq_path_position],state)]*emission_parameters[("#UNK#",state)]
                    
                    # Extend the sequence path
                    extended_seq_path = seq_path + [state]
                    
                    # Push the extended sequence into the heap
                    extended_seq = (extended_seq_score,extended_seq_path)
                    print(f"At state: {state}")
                    print(f"Managed to get Extended Sequence Path: {extended_seq_path} with Extended Sequence Score: {extended_seq_score}")
                    print("Pushing extended sequence into heap")
                    print(" ")
                    heapq.heappush(temp_sequences, extended_seq)
        print("##############################################")     
                
    all_sequences = temp_sequences
    
    print(f"All Sequences at Position: {position}:")
    print(all_sequences)
    print("############################################")
    print("############################################")
    print(" ")
    print(" ")
    #Increase the seq_path_position counter
    seq_path_position+=1
# Out:
# LOOKING AT POSITION 0
# Sequence Path: ['START'] with Sequence Score: 1
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O'] with Extended Sequence Score: 3.1991927574281916e-05
# Pushing extended sequence into heap
#
# At state: B-negative
# Managed to get Extended Sequence Path: ['START', 'B-negative'] with Extended Sequence Score: 3.6652034046920245e-05
# Pushing extended sequence into heap
#
# ##############################################
# All Sequences at Position: 0:
# [(3.1991927574281916e-05, ['START', 'O']), (3.6652034046920245e-05, ['START', 'B-negative'])]
# ############################################
# ############################################
#
#
# LOOKING AT POSITION 1
# Sequence Path: ['START', 'O'] with Sequence Score: 3.1991927574281916e-05
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O', 'O'] with Extended Sequence Score: 8.782693286363782e-09
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative'] with Sequence Score: 3.6652034046920245e-05
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'O'] with Extended Sequence Score: 9.213768724107643e-09
# Pushing extended sequence into heap
#
# At state: I-negative
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'I-negative'] with Extended Sequence Score: 7.606477187299569e-08
# Pushing extended sequence into heap
#
# ##############################################
# All Sequences at Position: 1:
# [(8.782693286363782e-09, ['START', 'O', 'O']), (9.213768724107643e-09, ['START', 'B-negative', 'O']), (7.606477187299569e-08, ['START', 'B-negative', 'I-negative'])]
# ############################################
# ############################################
#
#
# LOOKING AT POSITION 2
# Sequence Path: ['START', 'O', 'O'] with Sequence Score: 8.782693286363782e-09
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O', 'O', '
# Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O'] with Sequence Score: 4.87635535091235e-39
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O', 'O'] with Extended Sequence Score: 2.4141189489016197e-40
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O'] with Sequence Score: 5.1156984486330555e-39
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O', 'O'] with Extended Sequence Score: 2.5326096383441483e-40
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O'] with Sequence Score: 1.8961924474402013e-38
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O', 'O'] with Extended Sequence Score: 9.387408809887221e-40
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'] with Sequence Score: 1.1017753293854036e-35
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O'] with Extended Sequence Score: 5.454517787765372e-37
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'] with Sequence Score: 4.284302328306865e-35
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O'] with Extended Sequence Score: 2.1210134802119834e-36
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'] with Sequence Score: 1.1558530783086883e-35
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O'] with Extended Sequence Score: 5.722238470519184e-37
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] with Sequence Score: 2.0744731351214185e-33
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] with Extended Sequence Score: 1.0270016321814984e-34
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O'] with Sequence Score: 1.2753884115915887e-35
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'] with Extended Sequence Score: 6.3140175603829465e-37
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] with Sequence Score: 8.066680970038137e-33
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] with Extended Sequence Score: 3.9935414839834545e-34
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O'] with Sequence Score: 4.959404513373402e-35
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'] with Extended Sequence Score: 2.455233786184781e-36
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] with Sequence Score: 2.1762932016605502e-33
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] with Extended Sequence Score: 1.077409310523593e-34
# Pushing extended sequence into heap
#
# ##############################################
# Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O'] with Sequence Score: 1.337987502769451e-35
#
# At state: O
# Managed to get Extended Sequence Path: ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'] with Extended Sequence Score: 6.623924532540387e-37
# Pushing extended sequence into heap
#
# ##############################################
# All Sequences at Position: 12:
# [(2.4141189489016197e-40, ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O', 'O']), (2.5326096383441483e-40, ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O', 'O']), (9.387408809887221e-40, ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O', 'O']), (5.454517787765372e-37, ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O']), (2.1210134802119834e-36, ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O']), (5.722238470519184e-37, ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O']), (1.0270016321814984e-34, ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (6.3140175603829465e-37, ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O']), (3.9935414839834545e-34, ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (2.455233786184781e-36, ['START', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O']), (1.077409310523593e-34, ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (6.623924532540387e-37, ['START', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'])]
# ############################################
# ############################################

# %%
all_sequences
# Out:
# [(2.4141189489016197e-40,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'B-positive',
#    'O',
#    'O']),
#  (2.5326096383441483e-40,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'B-positive',
#    'O',
#    'O']),
#  (9.387408809887221e-40,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'B-positive',
#    'O',
#    'O']),
#  (5.454517787765372e-37,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O']),
#  (2.1210134802119834e-36,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O']),
#  (5.722238470519184e-37,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O']),
#  (1.0270016321814984e-34,
#   ['START', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (6.3140175603829465e-37,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O']),
#  (3.9935414839834545e-34,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (2.455233786184781e-36,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O']),
#  (1.077409310523593e-34,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (6.623924532540387e-37,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O'])]

# %% [markdown]
# #### Recursive Step of beam search at the last word

# %%
# Initialise a list to hold all temp sequences
temp_sequences = []

# For each sequence score and sequence path in the current top sequences
for seq_score, seq_path in all_sequences:

    # If the transition has been trained before
    if((seq_path[seq_path_position],"STOP") in transition_parameters.keys()):
        # Calculate the extended sequence score: 
        # score of current seq (product of transitions and emissions in seq) *
        # transiton prob of latest state in seq to STOP state  
        extended_seq_score = seq_score*transition_parameters[(seq_path[seq_path_position],state)]

        # Extend the sequence path
        extended_seq_path = seq_path + ["STOP"]

        # Push the extended sequence into the heap
        extended_seq = (extended_seq_score,extended_seq_path)
        heapq.heappush(temp_sequences, extended_seq)


#Prune step: Get the final top 8 sequences from all sequences
top_sequences = heapq.nlargest(k_sequences, temp_sequences)

#If no prediction is available for this sentence, assign a None value for all the states
if(len(top_sequences)==0):
    top_sequences = [(0, ['START'] + [None]*len(sentence) + ['STOP'])]

# %%
top_sequences
# Out:
# [(2.5335296757353274e-35,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (6.835157396192382e-36,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (6.515367682033133e-36,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (1.5576168879463979e-37,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'STOP']),
#  (1.3455852696919143e-37,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (4.202262438071084e-38,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'STOP']),
#  (4.00565536291558e-38,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'STOP']),
#  (3.630226713516906e-38,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O',
#    'STOP'])]

# %%
#In the case where the number of sequences generated is less than the number of sequences
#Pad the sequences using the last i.e. worst performing sequence
while(len(top_sequences)<8):
    top_sequences.append(copy.deepcopy(top_sequences[len(top_sequences)-1]))

# %%
top_sequences
# Out:
# [(2.5335296757353274e-35,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (6.835157396192382e-36,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (6.515367682033133e-36,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (1.5576168879463979e-37,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'STOP']),
#  (1.3455852696919143e-37,
#   ['START',
#    'B-negative',
#    'I-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O',
#    'STOP']),
#  (4.202262438071084e-38,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'STOP']),
#  (4.00565536291558e-38,
#   ['START',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'STOP']),
#  (3.630226713516906e-38,
#   ['START',
#    'B-negative',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-positive',
#    'O',
#    'O',
#    'O',
#    'STOP'])]

# %%
# Clean up the top_sequences to get only the predicted states
# for the top k sequences
for i in range(len(top_sequences)):
    temp = top_sequences[i][1]
    temp.pop(0)
    temp.pop(len(temp)-1)
    top_sequences[i] = temp

# %%
top_sequences
# Out:
# [['B-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O'],
#  ['B-negative',
#   'I-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O'],
#  ['B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O'],
#  ['B-negative',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-positive',
#   'O',
#   'O',
#   'O']]

# %%
# Combine the sentences with its predicted states
for i in range(len(top_sequences)):
    temp = [f"{sentence[j]} {top_sequences[i][j]}" for j in range(len(sentence))]
    top_sequences[i] = temp

# %%
top_sequences
# Out:
# [['Plato B-negative',
#   'degustación I-negative',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero O',
#   'bien O',
#   'cocinado O',
#   '. O'],
#  ['Plato B-negative',
#   'degustación O',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero O',
#   'bien O',
#   'cocinado O',
#   '. O'],
#  ['Plato O',
#   'degustación O',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero O',
#   'bien O',
#   'cocinado O',
#   '. O'],
#  ['Plato B-negative',
#   'degustación I-negative',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero O',
#   'bien B-positive',
#   'cocinado O',
#   '. O'],
#  ['Plato B-negative',
#   'degustación I-negative',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero B-positive',
#   'bien O',
#   'cocinado O',
#   '. O'],
#  ['Plato B-negative',
#   'degustación O',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero O',
#   'bien B-positive',
#   'cocinado O',
#   '. O'],
#  ['Plato O',
#   'degustación O',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero O',
#   'bien B-positive',
#   'cocinado O',
#   '. O'],
#  ['Plato B-negative',
#   'degustación O',
#   ': O',
#   'un O',
#   'poco O',
#   'abundante O',
#   'de O',
#   'más O',
#   ', O',
#   'pero B-positive',
#   'bien O',
#   'cocinado O',
#   '. O']]
